# %% [markdown]
# # 索引
# - `#` [1/1-1#コメント](1/1-1.ipynb#コメント)
# - `%` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - `*` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算), [5/5-1#from](5/5-1.ipynb#from), [5/5-4#モジュール](5/5-4.ipynb#モジュール)
# - `**` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - `+` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算), [1/1-1#単項の `+` と `-`](1/1-1.ipynb#単項の-+-と--)
# - `+=` [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - `-` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算), [1/1-1#単項の `+` と `-`](1/1-1.ipynb#単項の-+-と--)
# - `-=` [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - `/` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - `//` [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 3 項演算子 [3/3-1#▲3 項演算子（条件式）](3/3-1.ipynb#▲3-項演算子（条件式）)
# - `=` [1/1-2#代入文](1/1-2.ipynb#代入文)
# - `==` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - DataFrame [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - `False` [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - In place [2/2-2#破壊的（インプレース）な操作と非破壊的な生成](2/2-2.ipynb#破壊的（インプレース）な操作と非破壊的な生成)
# - `KMeans` [7/7-2#教師なし学習・クラスタリングの例](7/7-2.ipynb#教師なし学習・クラスタリングの例)
# - Matplotlib [5/5-3#▲Matplotlibライブラリ](5/5-3.ipynb#▲Matplotlibライブラリ)
# - `None` [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [1/1-3#▲None](1/1-3.ipynb#▲None)
# - NumPy [5/5-2#NumPyライブラリ](5/5-2.ipynb#NumPyライブラリ)
# - OOP [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - `PCA` [7/7-2#教師なし学習・次元削減の例](7/7-2.ipynb#教師なし学習・次元削減の例)
# - Series [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - `True` [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - `\` [3/3-1#▲複数行にまたがる条件式](3/3-1.ipynb#▲複数行にまたがる条件式)
# - `__class__` [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド)
# - `!=` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `>=` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `>` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `<=` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `<` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `LinearRegression` [7/7-2#教師あり学習・回帰の例](7/7-2.ipynb#教師あり学習・回帰の例)
# - `LogisticRegression` [7/7-2#教師あり学習・分類の例](7/7-2.ipynb#教師あり学習・分類の例)
# - `assign` [7/7-1#列の追加と削除](7/7-1.ipynb#列の追加と削除)
# - `close()` [4/4-1#属性](4/4-1.ipynb#属性)
# - `concat` [7/7-1#▲データの連結](7/7-1.ipynb#▲データの連結)
# - `delete` [5/5-2#delete()関数](5/5-2.ipynb#delete()関数)
# - `describe()` [7/7-1#データの統計量](7/7-1.ipynb#データの統計量)
# - `dot` [5/5-2#dot() 関数](5/5-2.ipynb#dot()-関数)
# - `drop` [7/7-1#列の追加と削除](7/7-1.ipynb#列の追加と削除), [7/7-1#行の追加と削除](7/7-1.ipynb#行の追加と削除)
# - `fit` [7/7-2#教師あり学習・分類の例](7/7-2.ipynb#教師あり学習・分類の例)
# - `flatten` [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - `grid` [5/5-3#線グラフ](5/5-3.ipynb#線グラフ)
# - `groupby` [7/7-1#▲データのグループ化](7/7-1.ipynb#▲データのグループ化)
# - `legend` [5/5-3#線グラフ](5/5-3.ipynb#線グラフ)
# - `linalg.norm` [5/5-2#linalg.norm() 関数](5/5-2.ipynb#linalg.norm()-関数)
# - `list` [2/2-2#タプル](2/2-2.ipynb#タプル)
# - `match` [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - `merge` [7/7-1#▲データの結合](7/7-1.ipynb#▲データの結合)
# - `ndim` [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - `not` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - `predict` [7/7-2#教師あり学習・分類の例](7/7-2.ipynb#教師あり学習・分類の例)
# - `random.gauss` [5/5-1#random](5/5-1.ipynb#random)
# - `random.randint` [5/5-1#random](5/5-1.ipynb#random)
# - `random.seed` [5/5-1#random](5/5-1.ipynb#random)
# - `ravel` [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - `re.IGNORECASE` [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - `re.I` [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - `read_csv` [7/7-1#csvファイルからのデータフレームの作成](7/7-1.ipynb#csvファイルからのデータフレームの作成)
# - `readline()` [4/4-1#行の読み込み](4/4-1.ipynb#行の読み込み)
# - `savefig` [5/5-3#グラフの画像ファイル出力](5/5-3.ipynb#グラフの画像ファイル出力)
# - `search` [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - `size` [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - `sort_index()` [7/7-1#データの並び替え](7/7-1.ipynb#データの並び替え)
# - `sort_values()` [7/7-1#データの並び替え](7/7-1.ipynb#データの並び替え)
# - `sqrt` [5/5-2#sqrt() 関数](5/5-2.ipynb#sqrt()-関数)
# - `strip()` [4/4-3#▲不要な空白や改行の除去](4/4-3.ipynb#▲不要な空白や改行の除去)
# - `title` [5/5-3#線グラフ](5/5-3.ipynb#線グラフ)
# - `transform` [7/7-2#教師なし学習・次元削減の例](7/7-2.ipynb#教師なし学習・次元削減の例)
# - `tuple` [2/2-2#タプル](2/2-2.ipynb#タプル)
# - `xlabel` [5/5-3#線グラフ](5/5-3.ipynb#線グラフ)
# - `ylabel` [5/5-3#線グラフ](5/5-3.ipynb#線グラフ)
# - add [2/2-4#add](2/2-4.ipynb#add)
# - `and` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - append [2/2-2#append](2/2-2.ipynb#append)
# - `arange` [5/5-2#arange()関数](5/5-2.ipynb#arange()関数)
# - `array` [5/5-2#配列の作成](5/5-2.ipynb#配列の作成)
# - `as` [4/4-1#ファイルに対する with 文](4/4-1.ipynb#ファイルに対する-with-文), [5/5-1#as](5/5-1.ipynb#as), [5/5-4#モジュール](5/5-4.ipynb#モジュール)
# - augmented assignment statement [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - `bar` [5/5-3#棒グラフ](5/5-3.ipynb#棒グラフ)
# - `break` [3/3-2#`break` 文](3/3-2.ipynb#-break-文)
# - `capitalize` [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - clear [2/2-3#clear](2/2-3.ipynb#clear), [2/2-4#clear](2/2-4.ipynb#clear)
# - continue [3/3-2#continue文](3/3-2.ipynb#continue文)
# - copy [2/2-2#copy](2/2-2.ipynb#copy), [2/2-3#copy](2/2-3.ipynb#copy)
# - `count` [2/2-1#数え上げ](2/2-1.ipynb#数え上げ)
# - `csv` [4/4-2#csv ファイルの読み込み](4/4-2.ipynb#csv-ファイルの読み込み), [4/4-2#csv ファイルの書き込み](4/4-2.ipynb#csv-ファイルの書き込み)
# - `csv.reader` [4/4-2#csv ファイルの読み込み](4/4-2.ipynb#csv-ファイルの読み込み)
# - `csv.writer` [4/4-2#csv ファイルの書き込み](4/4-2.ipynb#csv-ファイルの書き込み)
# - csvファイル [4/4-2#csv ファイルの読み込み](4/4-2.ipynb#csv-ファイルの読み込み), [7/7-1#csvファイルからのデータフレームの作成](7/7-1.ipynb#csvファイルからのデータフレームの作成)
# - csvライター [4/4-2#csv ファイルの書き込み](4/4-2.ipynb#csv-ファイルの書き込み)
# - csvリーダー [4/4-2#csv ファイルの読み込み](4/4-2.ipynb#csv-ファイルの読み込み)
# - `def` [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値)
# - del [2/2-2#del](2/2-2.ipynb#del)
# - difference [2/2-4#union, intersection, difference](2/2-4.ipynb#union,-intersection,-difference)
# - `dir` [4/4-1#属性](4/4-1.ipynb#属性)
# - discard [2/2-4#discard](2/2-4.ipynb#discard)
# - `elif` [3/3-1#`if` ... `elif` ... `else` による条件分岐](3/3-1.ipynb#-if-...-elif-...-else-による条件分岐)
# - `else` [1/1-3#`if` による条件分岐](1/1-3.ipynb#-if-による条件分岐), [3/3-1#`if` ... `else` による条件分岐](3/3-1.ipynb#-if-...-else-による条件分岐), [3/3-1#`if` ... `elif` ... `else` による条件分岐](3/3-1.ipynb#-if-...-elif-...-else-による条件分岐), [3/3-2#▲for, while 繰り返し文における `else`](3/3-2.ipynb#▲for,-while-繰り返し文における-else)
# - `encoding` [4/4-2#東京の7月の気温](4/4-2.ipynb#東京の7月の気温)
# - enumerate [3/3-2#enumerate関数](3/3-2.ipynb#enumerate関数)
# - extend [2/2-2#extend](2/2-2.ipynb#extend)
# - `find` [2/2-1#検索](2/2-1.ipynb#検索)
# - for [2/2-2#for文による繰り返しとリスト、タプル](2/2-2.ipynb#for文による繰り返しとリスト、タプル)
# - `from` [5/5-1#from](5/5-1.ipynb#from), [5/5-4#モジュール](5/5-4.ipynb#モジュール)
# - get [2/2-3#get](2/2-3.ipynb#get)
# - higher-order function [6/6-1#高階関数](6/6-1.ipynb#高階関数)
# - `hist` [5/5-3#ヒストグラム](5/5-3.ipynb#ヒストグラム)
# - `if` [1/1-3#`if` による条件分岐](1/1-3.ipynb#-if-による条件分岐), [3/3-1#条件分岐](3/3-1.ipynb#条件分岐), [3/3-1#`if` ... `else` による条件分岐](3/3-1.ipynb#-if-...-else-による条件分岐), [3/3-1#`if` ... `elif` ... `else` による条件分岐](3/3-1.ipynb#-if-...-elif-...-else-による条件分岐)
# - `iloc` [7/7-1#ilocとloc](7/7-1.ipynb#ilocとloc)
# - `import` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）), [5/5-1#モジュールの `import`](5/5-1.ipynb#モジュールの-import), [5/5-4#モジュール](5/5-4.ipynb#モジュール)
# - `in` [2/2-1#文字列の検索](2/2-1.ipynb#文字列の検索), [2/2-3#辞書](2/2-3.ipynb#辞書), [3/3-2#帰属演算子 `in`](3/3-2.ipynb#帰属演算子-in)
# - `index` [2/2-1#検索](2/2-1.ipynb#検索)
# - inheritance [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - insert [2/2-2#insert](2/2-2.ipynb#insert)
# - intersection [2/2-4#union, intersection, difference](2/2-4.ipynb#union,-intersection,-difference)
# - items [2/2-3#items](2/2-3.ipynb#items)
# - `json` [4/4-3#json ファイルのダンプとロード](4/4-3.ipynb#json-ファイルのダンプとロード)
# - `json.dump` [4/4-3#json ファイルのダンプとロード](4/4-3.ipynb#json-ファイルのダンプとロード)
# - `json.load` [4/4-3#json ファイルのダンプとロード](4/4-3.ipynb#json-ファイルのダンプとロード)
# - json形式 [4/4-3#json形式とは](4/4-3.ipynb#json形式とは)
# - keys [2/2-3#keys](2/2-3.ipynb#keys)
# - `len` [2/2-1#文字列](2/2-1.ipynb#文字列), [2/2-3#辞書](2/2-3.ipynb#辞書)
# - `linspace` [5/5-2#linspace()関数](5/5-2.ipynb#linspace()関数)
# - `loc` [7/7-1#ilocとloc](7/7-1.ipynb#ilocとloc)
# - `lower` [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - main [5/5-4#▲モジュールファイルの実行](5/5-4.ipynb#▲モジュールファイルの実行), [5/5-4#▲モジュールファイルの実行](5/5-4.ipynb#▲モジュールファイルの実行)
# - maintainability [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - matchオブジェクト [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - `math` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）), [5/5-1#math](5/5-1.ipynb#math)
# - `math.cos` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - `math.pi` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - `math.sin` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - `math.sqrt` [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - matplotlib [2/2-5#matplotlib](2/2-5.ipynb#matplotlib)
# - modularity [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - name [5/5-4#▲モジュールファイルの実行](5/5-4.ipynb#▲モジュールファイルの実行), [5/5-4#▲モジュールファイルの実行](5/5-4.ipynb#▲モジュールファイルの実行), [5/5-4#▲モジュールファイルの実行](5/5-4.ipynb#▲モジュールファイルの実行)
# - `next` [4/4-1#ファイルに対する for 文](4/4-1.ipynb#ファイルに対する-for-文), [4/4-2#csv ファイルの読み込み](4/4-2.ipynb#csv-ファイルの読み込み)
# - object-oriented programming [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - `ones` [5/5-2#ones()関数](5/5-2.ipynb#ones()関数)
# - `open` [4/4-1#ファイルのオープン](4/4-1.ipynb#ファイルのオープン)
# - `or` [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - pandas [7/7-1#pandasライブラリ](7/7-1.ipynb#pandasライブラリ)
# - `pass` [3/3-2#`pass` 文](3/3-2.ipynb#-pass-文)
# - `plot` [5/5-3#線グラフ](5/5-3.ipynb#線グラフ)
# - pop [2/2-2#pop](2/2-2.ipynb#pop), [2/2-3#pop](2/2-3.ipynb#pop), [2/2-4#pop](2/2-4.ipynb#pop)
# - `print` [1/1-2#print](1/1-2.ipynb#print)
# - `random` [5/5-1#random](5/5-1.ipynb#random)
# - `random.rand` [5/5-2#random.rand()関数](5/5-2.ipynb#random.rand()関数)
# - `random.random` [5/5-1#random](5/5-1.ipynb#random)
# - range [3/3-2#range関数](3/3-2.ipynb#range関数)
# - `read` [4/4-1#属性](4/4-1.ipynb#属性)
# - remove [2/2-2#remove](2/2-2.ipynb#remove), [2/2-4#remove](2/2-4.ipynb#remove)
# - `replace` [2/2-1#置換](2/2-1.ipynb#置換)
# - `reshape` [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - `return` [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-2#制御構造と `return`](3/3-2.ipynb#制御構造と-return)
# - reverse [2/2-2#reverse](2/2-2.ipynb#reverse)
# - `scatter` [5/5-3#散布図](5/5-3.ipynb#散布図)
# - scikit-learn [7/7-2#scikit-learnライブラリ](7/7-2.ipynb#scikit-learnライブラリ)
# - `set` [2/2-4#▲セット](2/2-4.ipynb#▲セット)
# - setdefault [2/2-3#setdefault](2/2-3.ipynb#setdefault)
# - `shape` [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - shebang行 [5/5-4#-*- coding: shift_jis -*-](5/5-4.ipynb#-*--coding:-shift_jis--*-), [5/5-4#-*- coding: shift_jis -*-](5/5-4.ipynb#-*--coding:-shift_jis--*-)
# - `sort` [2/2-2#メソッド `sort`](2/2-2.ipynb#メソッド-sort), [5/5-2#要素の並び替え](5/5-2.ipynb#要素の並び替え)
# - sorted [2/2-2#メソッド sorted](2/2-2.ipynb#メソッド-sorted)
# - split [5/5-5#re.split](5/5-5.ipynb#re.split)
# - `str` [2/2-1#文字列](2/2-1.ipynb#文字列)
# - sub [5/5-5#sub](5/5-5.ipynb#sub)
# - `sys` [5/5-4#プログラムへの引数の渡し方](5/5-4.ipynb#プログラムへの引数の渡し方)
# - `sys.argv` [5/5-4#プログラムへの引数の渡し方](5/5-4.ipynb#プログラムへの引数の渡し方)
# - `sys.path` [5/5-4#モジュールの検索パス](5/5-4.ipynb#モジュールの検索パス)
# - `time` [5/5-1#time](5/5-1.ipynb#time)
# - `time.localtime` [5/5-1#time](5/5-1.ipynb#time)
# - `time.time` [5/5-1#time](5/5-1.ipynb#time)
# - `type` [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド), [2/2-1#文字列](2/2-1.ipynb#文字列), [4/4-1#オブジェクト](4/4-1.ipynb#オブジェクト)
# - union [2/2-4#union, intersection, difference](2/2-4.ipynb#union,-intersection,-difference)
# - `upper` [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - values [2/2-3#values](2/2-3.ipynb#values)
# - `while` [3/3-2#`while` による繰り返し](3/3-2.ipynb#-while-による繰り返し)
# - `with` [4/4-1#ファイルに対する with 文](4/4-1.ipynb#ファイルに対する-with-文)
# - `write` [4/4-1#ファイルへの書き込み](4/4-1.ipynb#ファイルへの書き込み)
# - `writelines` [4/4-1#ファイルへの書き込み](4/4-1.ipynb#ファイルへの書き込み)
# - `zeros` [5/5-2#zeros()関数](5/5-2.ipynb#zeros()関数)
# - 余り [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - イテラブル [6/6-3#イテレータとイテラブルの定義](6/6-3.ipynb#イテレータとイテラブルの定義)
# - イテラブル（iterable） [6/6-3#イテラブルとfor文](6/6-3.ipynb#イテラブルとfor文)
# - イテレータ [3/3-3#▲ジェネレータ式](3/3-3.ipynb#▲ジェネレータ式), [4/4-1#ファイルに対する for 文](4/4-1.ipynb#ファイルに対する-for-文), [4/4-2#csv ファイルの読み込み](4/4-2.ipynb#csv-ファイルの読み込み), [6/6-3#イテレータとイテラブルの定義](6/6-3.ipynb#イテレータとイテラブルの定義)
# - 入れ子 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-1#`if` ... `else` による条件分岐](3/3-1.ipynb#-if-...-else-による条件分岐), [3/3-2#for文の入れ子](3/3-2.ipynb#for文の入れ子)
# - インスタンス [6/6-2#オブジェクトとクラス](6/6-2.ipynb#オブジェクトとクラス)
# - インデックス [2/2-1#文字列とインデックス](2/2-1.ipynb#文字列とインデックス), [5/5-2#インデックス](5/5-2.ipynb#インデックス), [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - インデント [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-1#インデントによる構文](3/3-1.ipynb#インデントによる構文)
# - インプレース [2/2-2#破壊的（インプレース）な操作と非破壊的な生成](2/2-2.ipynb#破壊的（インプレース）な操作と非破壊的な生成)
# - インポート [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）), [5/5-1#モジュールの `import`](5/5-1.ipynb#モジュールの-import)
# - エスケープシーケンス [2/2-1#エスケープシーケンス](2/2-1.ipynb#エスケープシーケンス)
# - エラー [1/1-1#エラー](1/1-1.ipynb#エラー)
# - オブジェクト [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド), [4/4-1#オブジェクト](4/4-1.ipynb#オブジェクト), [6/6-2#オブジェクトとクラス](6/6-2.ipynb#オブジェクトとクラス)
# - オブジェクト指向プログラミング [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - オーバーライド（override） [6/6-2#オーバーライド](6/6-2.ipynb#オーバーライド)
# - オープン [4/4-1#ファイルのオープン](4/4-1.ipynb#ファイルのオープン)
# - 返値 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-4#返値](3/3-4.ipynb#返値)
# - 書き込みモード [4/4-1#ファイルへの書き込み](4/4-1.ipynb#ファイルへの書き込み)
# - 掛け算 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 数え上げ [2/2-1#数え上げ](2/2-1.ipynb#数え上げ)
# - 型 [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド), [4/4-1#オブジェクト](4/4-1.ipynb#オブジェクト)
# - 括弧 [1/1-1#演算子の優先順位と括弧](1/1-1.ipynb#演算子の優先順位と括弧)
# - 仮引数 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-4#引数](3/3-4.ipynb#引数)
# - カレントディレクトリ [4/4-4#カレントディレクトリ](4/4-4.ipynb#カレントディレクトリ)
# - 関数 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-4#関数の定義](3/3-4.ipynb#関数の定義)
# - 関数定義 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値)
# - 機械学習 [7/7-2#機械学習について](7/7-2.ipynb#機械学習について)
# - 教師あり学習 [7/7-2#教師あり学習](7/7-2.ipynb#教師あり学習)
# - 教師なし学習 [7/7-2#教師なし学習](7/7-2.ipynb#教師なし学習)
# - キー(key) [2/2-3#辞書](2/2-3.ipynb#辞書)
# - 偽 [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - 行列積 [5/5-2#▲行列の演算](5/5-2.ipynb#▲行列の演算)
# - 空行 [1/1-2#コメントと空行](1/1-2.ipynb#コメントと空行)
# - 空白 [1/1-1#空白](1/1-1.ipynb#空白)
# - 空文字列 [2/2-1#空文字列](2/2-1.ipynb#空文字列), [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - 空列 [2/2-1#空文字列](2/2-1.ipynb#空文字列), [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - クラス [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - クラスタリング [7/7-2#教師なし学習・クラスタリングの例](7/7-2.ipynb#教師なし学習・クラスタリングの例)
# - 繰り返し [3/3-2#繰り返し](3/3-2.ipynb#繰り返し)
# - クローズ [4/4-1#属性](4/4-1.ipynb#属性)
# - グローバル変数 [1/1-2#▲グローバル変数](1/1-2.ipynb#▲グローバル変数), [3/3-4#変数とスコープ](3/3-4.ipynb#変数とスコープ)
# - 継承 [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - 検索 [2/2-1#検索](2/2-1.ipynb#検索)
# - 高階関数 [6/6-1#高階関数](6/6-1.ipynb#高階関数)
# - 子クラス [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - コメント [1/1-1#コメント](1/1-1.ipynb#コメント), [1/1-2#コメントと空行](1/1-2.ipynb#コメントと空行)
# - 小文字 [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - コンストラクタ [6/6-2#オブジェクトとクラス](6/6-2.ipynb#オブジェクトとクラス)
# - 再帰 [1/1-3#▲再帰](1/1-3.ipynb#▲再帰)
# - 再帰関数 [3/3-5#▲再帰](3/3-5.ipynb#▲再帰)
# - 差集合 [2/2-4#集合演算](2/2-4.ipynb#集合演算), [2/2-4#union, intersection, difference](2/2-4.ipynb#union,-intersection,-difference)
# - 参照値 [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド), [4/4-1#オブジェクト](4/4-1.ipynb#オブジェクト)
# - 集合演算 [2/2-4#集合演算](2/2-4.ipynb#集合演算)
# - 集合内包表記 [3/3-3#▲集合内包表記](3/3-3.ipynb#▲集合内包表記)
# - シリーズ [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - 真 [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - 親クラス [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - ジェネレータ [6/6-3#ジェネレータ関数と無限イテレータ](6/6-3.ipynb#ジェネレータ関数と無限イテレータ)
# - ジェネレータイテレータ [6/6-3#ジェネレータ関数と無限イテレータ](6/6-3.ipynb#ジェネレータ関数と無限イテレータ)
# - ジェネレータ関数 [6/6-3#ジェネレータ関数と無限イテレータ](6/6-3.ipynb#ジェネレータ関数と無限イテレータ)
# - ジェネレータ式 [3/3-3#▲ジェネレータ式](3/3-3.ipynb#▲ジェネレータ式)
# - 次元削減 [7/7-2#教師なし学習・次元削減の例](7/7-2.ipynb#教師なし学習・次元削減の例)
# - 辞書 [2/2-3#辞書](2/2-3.ipynb#辞書)
# - 辞書内包表記 [3/3-3#▲辞書内包表記](3/3-3.ipynb#▲辞書内包表記)
# - 実行エラー [1/1-1#エラー](1/1-1.ipynb#エラー), [1/1-4#デバッグ](1/1-4.ipynb#デバッグ), [1/1-4#実行エラー：Runtime Errors](1/1-4.ipynb#実行エラー：Runtime-Errors)
# - 実数 [1/1-1#整数と実数](1/1-1.ipynb#整数と実数)
# - 条件付き内包表記 [3/3-3#▲条件付き内包表記](3/3-3.ipynb#▲条件付き内包表記)
# - 条件分岐 [1/1-3#`if` による条件分岐](1/1-3.ipynb#-if-による条件分岐), [3/3-1#条件分岐](3/3-1.ipynb#条件分岐)
# - スライス [2/2-1#文字列とスライス](2/2-1.ipynb#文字列とスライス), [5/5-2#スライス](5/5-2.ipynb#スライス), [7/7-1#データの参照](7/7-1.ipynb#データの参照)
# - 正規表現 [5/5-5#正規表現](5/5-5.ipynb#正規表現)
# - 整除 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 整数 [1/1-1#整数と実数](1/1-1.ipynb#整数と実数)
# - 積集合 [2/2-4#集合演算](2/2-4.ipynb#集合演算), [2/2-4#union, intersection, difference](2/2-4.ipynb#union,-intersection,-difference)
# - セット [2/2-4#▲セット](2/2-4.ipynb#▲セット)
# - 線形回帰 [4/4-2#東京の7月の気温](4/4-2.ipynb#東京の7月の気温), [7/7-2#教師あり学習・回帰の例](7/7-2.ipynb#教師あり学習・回帰の例)
# - 空のリスト [2/2-2#リスト](2/2-2.ipynb#リスト)
# - 空リスト [2/2-2#リスト](2/2-2.ipynb#リスト)
# - 属性 [4/4-1#属性](4/4-1.ipynb#属性)
# - 対称差 [2/2-4#集合演算](2/2-4.ipynb#集合演算), [2/2-4#union, intersection, difference](2/2-4.ipynb#union,-intersection,-difference)
# - 足し算 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 多次元配列 [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - 多重代入 [2/2-2#多重代入](2/2-2.ipynb#多重代入), [2/2-2#タプル](2/2-2.ipynb#タプル)
# - 多重リスト [2/2-2#多重リスト](2/2-2.ipynb#多重リスト)
# - タプル [2/2-2#タプル](2/2-2.ipynb#タプル)
# - 単項 [1/1-1#単項の `+` と `-`](1/1-1.ipynb#単項の-+-と--)
# - 代入 [1/1-2#代入文](1/1-2.ipynb#代入文)
# - 代入演算子 [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - 大文字 [2/2-1#大文字・小文字](2/2-1.ipynb#大文字・小文字)
# - 置換 [2/2-1#置換](2/2-1.ipynb#置換)
# - デバッグ [1/1-2#print](1/1-2.ipynb#print), [1/1-4#デバッグ](1/1-4.ipynb#デバッグ)
# - データフレーム [7/7-1#シリーズとデータフレーム](7/7-1.ipynb#シリーズとデータフレーム)
# - 特徴量 [7/7-2#データ](7/7-2.ipynb#データ)
# - 内積 [5/5-2#▲行列の演算](5/5-2.ipynb#▲行列の演算)
# - 内包表記 [3/3-3#内包表記](3/3-3.ipynb#内包表記)
# - ネスト [3/3-1#`if` ... `else` による条件分岐](3/3-1.ipynb#-if-...-else-による条件分岐)
# - 配列 [2/2-2#リスト](2/2-2.ipynb#リスト), [5/5-2#配列の作成](5/5-2.ipynb#配列の作成)
# - 破壊的 [2/2-2#破壊的（インプレース）な操作と非破壊的な生成](2/2-2.ipynb#破壊的（インプレース）な操作と非破壊的な生成)
# - 半角の空白 [1/1-1#空白](1/1-1.ipynb#空白)
# - バグ [1/1-2#print](1/1-2.ipynb#print), [1/1-4#デバッグ](1/1-4.ipynb#デバッグ)
# - パス [4/4-4#カレントディレクトリ](4/4-4.ipynb#カレントディレクトリ)
# - パターン [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - パッケージ [5/5-4#▲パッケージ](5/5-4.ipynb#▲パッケージ)
# - 比較演算 [2/2-4#比較演算](2/2-4.ipynb#比較演算)
# - 比較演算子 [1/1-3#様々な条件](1/1-3.ipynb#様々な条件)
# - 引き算 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 引数 [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [1/1-2#関数の定義と返値](1/1-2.ipynb#関数の定義と返値), [3/3-4#関数の定義](3/3-4.ipynb#関数の定義)
# - ファイル [4/4-1#ファイルのオープン](4/4-1.ipynb#ファイルのオープン)
# - 浮動小数点数 [1/1-1#整数と実数](1/1-1.ipynb#整数と実数)
# - ブロードキャスト [5/5-2#配列の演算](5/5-2.ipynb#配列の演算)
# - 分割 [2/2-1#分割](2/2-1.ipynb#分割)
# - 文法エラー [1/1-1#エラー](1/1-1.ipynb#エラー), [1/1-4#デバッグ](1/1-4.ipynb#デバッグ), [1/1-4#文法エラー：Syntax Errors](1/1-4.ipynb#文法エラー：Syntax-Errors)
# - ブールインデックス参照 [5/5-2#▲要素の条件取り出し](5/5-2.ipynb#▲要素の条件取り出し), [7/7-1#データの条件取り出し](7/7-1.ipynb#データの条件取り出し)
# - 変数 [1/1-2#変数](1/1-2.ipynb#変数), [2/2-1#初心者によくある誤解、変数と文字列の混乱](2/2-1.ipynb#初心者によくある誤解、変数と文字列の混乱)
# - べき乗 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - べき表示 [1/1-1#実数のべき表示](1/1-1.ipynb#実数のべき表示)
# - マッチする [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本), [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - 無名関数 [6/6-1#高階関数](6/6-1.ipynb#高階関数)
# - メソッド [1/1-3#▲オブジェクトと属性・メソッド](1/1-3.ipynb#▲オブジェクトと属性・メソッド), [2/2-1#文字列とメソッド](2/2-1.ipynb#文字列とメソッド), [4/4-1#属性](4/4-1.ipynb#属性), [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - 文字コード [4/4-2#東京の7月の気温](4/4-2.ipynb#東京の7月の気温)
# - モジュール [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）), [5/5-1#モジュールの `import`](5/5-1.ipynb#モジュールの-import), [5/5-4#モジュール](5/5-4.ipynb#モジュール)
# - モジュール名 [5/5-4#モジュール](5/5-4.ipynb#モジュール)
# - モジュール性 [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - 文字列 [2/2-1#文字列](2/2-1.ipynb#文字列), [2/2-1#初心者によくある誤解、変数と文字列の混乱](2/2-1.ipynb#初心者によくある誤解、変数と文字列の混乱)
# - 文字列の比較演算 [2/2-1#文字列の比較演算](2/2-1.ipynb#文字列の比較演算)
# - 優先順位 [1/1-1#演算子の優先順位と括弧](1/1-1.ipynb#演算子の優先順位と括弧)
# - ユニバーサル関数 [5/5-2#配列の演算](5/5-2.ipynb#配列の演算)
# - 読み込みモード [4/4-1#ファイルのオープン](4/4-1.ipynb#ファイルのオープン)
# - ライブラリ [1/1-1#数学関数（モジュールの `import`）](1/1-1.ipynb#数学関数（モジュールの-import-）)
# - ラムダ式 [6/6-1#高階関数](6/6-1.ipynb#高階関数)
# - リスト [2/2-2#リスト](2/2-2.ipynb#リスト)
# - ループ [3/3-2#`for` による繰り返し](3/3-2.ipynb#-for-による繰り返し)
# - レシーバ [6/6-2#クラス定義](6/6-2.ipynb#クラス定義)
# - ロジスティック回帰 [7/7-2#教師あり学習・分類の例](7/7-2.ipynb#教師あり学習・分類の例)
# - 論理エラー [1/1-4#デバッグ](1/1-4.ipynb#デバッグ), [1/1-4#論理エラー：Logical Errors](1/1-4.ipynb#論理エラー：Logical-Errors)
# - ローカル変数 [1/1-2#ローカル変数](1/1-2.ipynb#ローカル変数), [3/3-4#引数](3/3-4.ipynb#引数)
# - ワイルドカード [5/5-1#from](5/5-1.ipynb#from)
# - 和集合 [2/2-4#集合演算](2/2-4.ipynb#集合演算), [2/2-4#union, intersection, difference](2/2-4.ipynb#union,-intersection,-difference)
# - 割り算 [1/1-1#簡単な算術計算](1/1-1.ipynb#簡単な算術計算)
# - 乱数 [5/5-1#random](5/5-1.ipynb#random)
# - 予約語 [1/1-2#予約語](1/1-2.ipynb#予約語)
# - 保守性 [6/6-2#オブジェクト指向の考え方](6/6-2.ipynb#オブジェクト指向の考え方)
# - 値(value) [2/2-3#辞書](2/2-3.ipynb#辞書)
# - 再帰呼出し [3/3-5#▲再帰](3/3-5.ipynb#▲再帰)
# - 分割統治 [3/3-5#▲再帰](3/3-5.ipynb#▲再帰)
# - 列 [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - 名前付きタプル [6/6-2#▲名前付きタプル](6/6-2.ipynb#▲名前付きタプル)
# - 否定文字クラス [5/5-5#否定文字クラス](5/5-5.ipynb#否定文字クラス)
# - 和 [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - 実引数 [3/3-4#引数](3/3-4.ipynb#引数)
# - 文字クラス [5/5-5#文字クラス](5/5-5.ipynb#文字クラス), [5/5-5#文字クラス](5/5-5.ipynb#文字クラス)
# - 注意 [1/1-2#代入文](1/1-2.ipynb#代入文)
# - 相対パス [4/4-4#相対パスと絶対パス](4/4-4.ipynb#相対パスと絶対パス)
# - 真理値 [1/1-3#真理値を返す関数](1/1-3.ipynb#真理値を返す関数)
# - 累算代入文 [1/1-2#累積代入文](1/1-2.ipynb#累積代入文)
# - 絶対パス [4/4-4#相対パスと絶対パス](4/4-4.ipynb#相対パスと絶対パス)
# - 行 [5/5-2#多次元配列の作成](5/5-2.ipynb#多次元配列の作成)
# - 連接 [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - 選択 [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - 閉包 [5/5-5#正規表現の基本](5/5-5.ipynb#正規表現の基本)
# - 関数プログラミング [6/6-1#関数プログラミング](6/6-1.ipynb#関数プログラミング)
# - 非破壊的 [2/2-2#破壊的（インプレース）な操作と非破壊的な生成](2/2-2.ipynb#破壊的（インプレース）な操作と非破壊的な生成)
