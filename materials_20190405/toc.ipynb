# %% [markdown]
# ▲で始まる項目は授業では扱いません。興味にしたがって学習してください。
#
# notebook全体に▲が付いているものもありますので注意してください。

# %% [markdown]
# # 第1回
#
# ## [1-0 Jupyter Notebookの使い方](1/1-0.ipynb)
# * セル
# * コマンドモード
# * 編集モード
# * （注意）Shift-Enterに反応がなくなったとき
#
# ## [1-1 数値演算](1/1-1.ipynb)
# * 簡単な算術計算
# * コメント
# * 整数と実数
# * 演算子の優先順位と括弧
# * 算術演算子のまとめ
# * 空白
# * エラー
# * 数学関数（モジュールの `import`）
#
# ## [1-2 変数と関数の基礎](1/1-2.ipynb)
# * 変数
# * 関数の定義と返値
# * ローカル変数
# * print
# * print と return
# * コメントと空行
# * 関数の参照の書き方
# * ▲グローバル変数
#
# ## [1-3 論理・比較演算と条件分岐の基礎](1/1-3.ipynb)
# * `if` による条件分岐
# * 様々な条件
# * 真理値を返す関数
# * ▲再帰
# * ▲条件として使われる他の値
# * ▲None
# * ▲オブジェクトと属性・メソッド
#
# ## [1-4 デバッグ](1/1-4.ipynb)
# * 文法エラー：Syntax Errors
# * 実行エラー：Runtime Errors
# * 論理エラー：Logical Errors
# * printによるデバッグ
# * ▲assert文によるデバッグ

# %% [markdown]
# # 第2回
#
# ## [2-1 文字列](2/2-1.ipynb)
# * 文字列とインデックス
# * 文字列とスライス
# * 空文字列
# * 文字列の検索
# * エスケープシーケンス
# * 文字列の連結
# * 文字列とメソッド
# * 文字列の比較演算
# * 初心者によくある誤解、変数と文字列の混乱
#
# ## [2-2 リスト](2/2-2.ipynb)
# * リストとインデックス
# * 多重代入
# * 多重リスト
# * リストの操作
# * 破壊的（インプレース）な操作と非破壊的な生成
# * リストの操作（2）
# * タプル
# * リストやタプルの比較演算
# * 比較演算子 `==`, `!=` と `is`, `is not`
# * for文による繰り返しとリスト、タプル
# * for文による繰り返しと文字列
#
# ## [2-3 辞書](2/2-3.ipynb)
# * 辞書のメソッド
# * ▲ keys, values, items の返り値
# * 辞書とリスト
# * for文による繰り返しと辞書
#
# ## [▲2-4 セット](2/2-4.ipynb)
# * セットの組み込み関数
# * 集合演算
# * 比較演算
# * セットのメソッド
#
# ## [▲2-5 簡単なデータの可視化](2/2-5.ipynb)
# * matplotlib
# * 折れ線グラフ
# * 散布図
# * 棒グラフ

# %% [markdown]
# # 第3回
#
# ## [3-1 条件分岐](3/3-1.ipynb)
# * インデントによる構文
# * #によるコメント
# * `if` ... `else` による条件分岐
# * `if` ... `elif` ... `else` による条件分岐
# * ▲複数行にまたがる条件式
# * 条件分岐の順番
# * 分岐の評価
# * ▲3項演算子（条件式）
#
# ## [3-2 繰り返し](3/3-3.ipynb)
# * `for` による繰り返し
# * 辞書に対する繰り返し処理
# * range関数
# * range関数とリスト
# * for文の入れ子
# * enumerate関数
# * 帰属演算子 `in`
# * `while` による繰り返し
# * 制御構造と `return`
# * `break` 文
# * continue文
# * ▲for, while 繰り返し文における `else`
# * `pass` 文
#
# ## [3-3 内包表記](3/3-3.ipynb)
# * リスト内包表記
# * 内包表記のネスト
# * ▲条件付き内包表記
# * ▲集合内包表記
# * ▲辞書内包表記
# * ▲ジェネレータ式
#
# ## [3-4 関数](3/3-4.ipynb)
# * 関数の定義
# * 引数
# * 返値
# * 複数の引数
# * 変数とスコープ
# * ▲キーワード引数
# * ▲引数の初期値
# * ▲可変長の引数
# * ▲辞書型の可変長引数
# * ▲引数の順番
# * ▲変数としての関数
#
# ## [▲3-5 再帰](3/3-5.ipynb)
# * 再帰関数の例：接頭辞リストと接尾辞リスト
# * 再帰関数の例：べき乗の計算
# * 再帰関数の例：マージソート

# %% [markdown]
# # 第4回
#
# ## [4-1 ファイル入出力の基本](4/4-1.ipynb)
# * ファイルのオープン
# * オブジェクト
# * ファイルに対する for 文
# * 行の読み込み
# * ファイルに対する with 文
# * ファイルへの書き込み
#
# ## [4-2 csv ファイルの入出力](4/4-2.ipynb)
# * csv形式とは
# * csv ファイルの読み込み
# * csv ファイルに対する for 文
# * csv ファイルに対する with 文
# * csv ファイルの書き込み
#
# ## [4-3 json ファイルの入出力](4/4-3.ipynb)
# * json形式とは
# * json ファイルのダンプとロード
# * ▲不要な空白や改行の除去
#
# ## [▲4-4 木構造のデータ形式](4/4-4.ipynb)
# * カレントディレクトリ
# * 相対パスと絶対パス
# * カレントディレクトリの移動
# * 木構造によるデータ表現
# * テキストによる木構造のデータ表現
# * 木構造のjson表現

# %% [markdown]
# # 第5回
#
# ## [5-1 モジュールの使い方](5/5-1.ipynb)
# * モジュールの import
# * from
# * as
# * パッケージ
# * math
# * random
# * time
#
# ## [5-2 NumPyライブラリ](5/5-2.ipynb)
# * 配列の作成
# * 多次元配列の作成
# * 様々な配列の作り方
# * 配列要素の操作
# * 配列の演算
# * 配列同士の演算
# * NumPyの関数
# * 文字列型の配列
# * ▲配列要素の追加、挿入、削除
# * ▲要素の条件取り出し
# * ▲ブロードキャスト
# * ▲行列の演算
#
# ## [▲5-3 Matplotlibライブラリ](5/5-3.ipynb)
# * 線グラフ
# * 散布図
# * 棒グラフ
# * ヒストグラム
# * ヒートマップ
# * グラフの画像ファイル出力
#
# ## [5-4 Python 実行ファイルとモジュール](5/5-4.ipynb)
# * Python プログラムファイル
# * プログラムファイルの文字コード
# * jupyter-notebook で Python プログラムファイル (.py) を扱う
# * プログラムへの引数の渡し方
# * モジュール
# * モジュールの検索パス
# * ▲モジュールファイルの実行
# * ▲パッケージ
#
# ## [5-5 正規表現](5/5-5.ipynb)
# * 正規表現の基本
# * 正規表現の応用1
# * 正規表現に関する基本的な関数
# * ▲正規表現の応用2
# * ▲正規表現に関する関数とメソッド

# %% [markdown]
# # 第6回
#
# ## [6-1 関数プログラミング](6/6-1.ipynb)
# * 高階関数
# * イテレータ
# * イテレータを生成する関数
# * ▲関数内関数（クロージャ）
# * オブジェクトの初期化
# * 引数による初期化
# * ▲属性の検査、追加、変更、削除（組み込み関数による方法）
# * ▲クラス変数
#
# ## [6-2 オブジェクト指向プログラミング](6/6-2.ipynb)
# * 派生クラスの定義
# * 属性・メソッドの上書き
# * 基底クラスのメソッド呼び出し
# * ▲継承関係を検査する関数
#
# ## [▲6-3 イテレータとイテラブル](6/6-3.ipynb)
# * ジェネレータ関数と無限イテレータ
# * イテラブルとfor文
# * イテレータとイテラブルの定義
# * コレクションの階層

# %% [markdown]
# # 第7回
#
# ## [7-1 pandasライブラリ](7/7-1.ipynb)
# * シリーズとデータフレーム
# * シリーズ（Series）の作成
# * データフレーム（DataFrame）の作成
# * csvファイルからのデータフレームの作成
# * データの参照
# * データの条件取り出し
# * 列の追加と削除
# * 行の追加と削除
# * データの並び替え
# * データの統計量
# * ▲データの連結
# * ▲データの結合
# * ▲データのグループ化
# * ▲欠損値、時系列データの処理
#
# ## [7-2 scikit-learnライブラリ](7/7-2.ipynb)
# * 機械学習について
# * 教師あり学習
# * 教師なし学習
# * データ
# * モデル学習の基礎
# * 教師あり学習・分類の例
# * 教師あり学習・回帰の例
# * 教師なし学習・クラスタリングの例
# * 教師なし学習・次元削減の例
